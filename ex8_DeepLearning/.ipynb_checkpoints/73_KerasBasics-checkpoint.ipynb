# %%
import numpy as np
from numpy import genfromtxt

# %%
data = genfromtxt('../DATA/bank_note_data.txt', delimiter=",")

# %%
data
# Out:
# array([[  3.6216 ,   8.6661 ,  -2.8073 ,  -0.44699,   0.     ],
#        [  4.5459 ,   8.1674 ,  -2.4586 ,  -1.4621 ,   0.     ],
#        [  3.866  ,  -2.6383 ,   1.9242 ,   0.10645,   0.     ],
#        ...,
#        [ -3.7503 , -13.4586 ,  17.5932 ,  -2.7771 ,   1.     ],
#        [ -3.5637 ,  -8.3827 ,  12.393  ,  -1.2823 ,   1.     ],
#        [ -2.5419 ,  -0.65804,   2.6842 ,   1.1952 ,   1.     ]])

# %%
labels=data[:,4]
labels
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
features=data[:,0:4]

# %%
features
# Out:
# array([[  3.6216 ,   8.6661 ,  -2.8073 ,  -0.44699],
#        [  4.5459 ,   8.1674 ,  -2.4586 ,  -1.4621 ],
#        [  3.866  ,  -2.6383 ,   1.9242 ,   0.10645],
#        ...,
#        [ -3.7503 , -13.4586 ,  17.5932 ,  -2.7771 ],
#        [ -3.5637 ,  -8.3827 ,  12.393  ,  -1.2823 ],
#        [ -2.5419 ,  -0.65804,   2.6842 ,   1.1952 ]])

# %%
X = features
y= labels

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Standardize or scale your data
from sklearn.preprocessing import MinMaxScaler

scaler_object = MinMaxScaler()
scaler_object.fit(X_train)

scaled_X_train=scaler_object.transform(X_train)
scaled_X_test=scaler_object.transform(X_test)

# %% [markdown]
# ## Build neuron network model

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential() # Build a model

model.add(Dense(4, input_dim=4,activation='relu'))  # Imamo 4 stolpce-dimenzije za input. Kao imamo 4 nevrone ZGLEDA da je to vhodni layer
model.add(Dense(8, activation='relu')) # vmesni layer Hidden Layer
model.add(Dense(1,activation='sigmoid')) #IZHODNI Layer -Samo eno stanje

# %% [markdown]
# ### Compile the model, Train it and testing it

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train data
model.fit(scaled_X_train, y_train, epochs=50, verbose=2) # verbose=2 --> pomeni, da bom med treningom izpisovalo na ekranu poročilo
# Out:
# Epoch 1/50
# 29/29 - 1s - loss: 0.2229 - accuracy: 0.9630 - 536ms/epoch - 18ms/step
# Epoch 2/50
# 29/29 - 0s - loss: 0.2187 - accuracy: 0.9652 - 28ms/epoch - 964us/step
# Epoch 3/50
# 29/29 - 0s - loss: 0.2130 - accuracy: 0.9641 - 28ms/epoch - 964us/step
# Epoch 4/50
# 29/29 - 0s - loss: 0.2074 - accuracy: 0.9641 - 28ms/epoch - 965us/step
# Epoch 5/50
# 29/29 - 0s - loss: 0.2028 - accuracy: 0.9641 - 29ms/epoch - 1ms/step
# Epoch 6/50
# 29/29 - 0s - loss: 0.1996 - accuracy: 0.9663 - 28ms/epoch - 966us/step
# Epoch 7/50
# 29/29 - 0s - loss: 0.1934 - accuracy: 0.9663 - 28ms/epoch - 966us/step
# Epoch 8/50
# 29/29 - 0s - loss: 0.1897 - accuracy: 0.9630 - 28ms/epoch - 966us/step
# Epoch 9/50
# 29/29 - 0s - loss: 0.1854 - accuracy: 0.9663 - 28ms/epoch - 965us/step
# Epoch 10/50
# 29/29 - 0s - loss: 0.1809 - accuracy: 0.9652 - 28ms/epoch - 966us/step
# Epoch 11/50
# 29/29 - 0s - loss: 0.1770 - accuracy: 0.9728 - 28ms/epoch - 966us/step
# Epoch 12/50
# 29/29 - 0s - loss: 0.1735 - accuracy: 0.9663 - 27ms/epoch - 931us/step
# Epoch 13/50
# 29/29 - 0s - loss: 0.1713 - accuracy: 0.9674 - 28ms/epoch - 966us/step
# Epoch 14/50
# 29/29 - 0s - loss: 0.1659 - accuracy: 0.9706 - 28ms/epoch - 966us/step
# Epoch 15/50
# 29/29 - 0s - loss: 0.1625 - accuracy: 0.9717 - 28ms/epoch - 966us/step
# Epoch 16/50
# 29/29 - 0s - loss: 0.1594 - accuracy: 0.9717 - 28ms/epoch - 966us/step
# Epoch 17/50
# 29/29 - 0s - loss: 0.1564 - accuracy: 0.9695 - 31ms/epoch - 1ms/step
# Epoch 18/50
# 29/29 - 0s - loss: 0.1530 - accuracy: 0.9717 - 31ms/epoch - 1ms/step
# Epoch 19/50
# 29/29 - 0s - loss: 0.1501 - accuracy: 0.9717 - 31ms/epoch - 1ms/step
# Epoch 20/50
# 29/29 - 0s - loss: 0.1477 - accuracy: 0.9761 - 27ms/epoch - 931us/step
# Epoch 21/50
# 29/29 - 0s - loss: 0.1444 - accuracy: 0.9750 - 28ms/epoch - 966us/step
# Epoch 22/50
# 29/29 - 0s - loss: 0.1423 - accuracy: 0.9771 - 28ms/epoch - 965us/step
# Epoch 23/50
# 29/29 - 0s - loss: 0.1394 - accuracy: 0.9782 - 29ms/epoch - 1ms/step
# Epoch 24/50
# 29/29 - 0s - loss: 0.1366 - accuracy: 0.9771 - 28ms/epoch - 965us/step
# Epoch 25/50
# 29/29 - 0s - loss: 0.1347 - accuracy: 0.9782 - 28ms/epoch - 966us/step
# Epoch 26/50
# 29/29 - 0s - loss: 0.1317 - accuracy: 0.9804 - 29ms/epoch - 1ms/step
# Epoch 27/50
# 29/29 - 0s - loss: 0.1296 - accuracy: 0.9793 - 29ms/epoch - 999us/step
# Epoch 28/50
# 29/29 - 0s - loss: 0.1276 - accuracy: 0.9761 - 28ms/epoch - 965us/step
# Epoch 29/50
# 29/29 - 0s - loss: 0.1249 - accuracy: 0.9793 - 29ms/epoch - 999us/step
# Epoch 30/50
# 29/29 - 0s - loss: 0.1231 - accuracy: 0.9761 - 28ms/epoch - 966us/step
# Epoch 31/50
# 29/29 - 0s - loss: 0.1205 - accuracy: 0.9826 - 29ms/epoch - 1000us/step
# Epoch 32/50
# 29/29 - 0s - loss: 0.1185 - accuracy: 0.9804 - 28ms/epoch - 966us/step
# Epoch 33/50
# 29/29 - 0s - loss: 0.1169 - accuracy: 0.9793 - 28ms/epoch - 965us/step
# Epoch 34/50
# 29/29 - 0s - loss: 0.1145 - accuracy: 0.9793 - 29ms/epoch - 1000us/step
# Epoch 35/50
# 29/29 - 0s - loss: 0.1133 - accuracy: 0.9804 - 28ms/epoch - 966us/step
# Epoch 36/50
# 29/29 - 0s - loss: 0.1111 - accuracy: 0.9826 - 27ms/epoch - 930us/step
# Epoch 37/50
# 29/29 - 0s - loss: 0.1091 - accuracy: 0.9793 - 29ms/epoch - 1ms/step
# Epoch 38/50
# 29/29 - 0s - loss: 0.1082 - accuracy: 0.9793 - 28ms/epoch - 966us/step
# Epoch 39/50
# 29/29 - 0s - loss: 0.1066 - accuracy: 0.9804 - 28ms/epoch - 966us/step
# Epoch 40/50
# 29/29 - 0s - loss: 0.1043 - accuracy: 0.9804 - 28ms/epoch - 965us/step
# Epoch 41/50
# 29/29 - 0s - loss: 0.1023 - accuracy: 0.9793 - 29ms/epoch - 1ms/step
# Epoch 42/50
# 29/29 - 0s - loss: 0.1009 - accuracy: 0.9815 - 29ms/epoch - 999us/step
# Epoch 43/50
# 29/29 - 0s - loss: 0.1006 - accuracy: 0.9793 - 28ms/epoch - 966us/step
# Epoch 44/50
# 29/29 - 0s - loss: 0.0985 - accuracy: 0.9793 - 28ms/epoch - 965us/step
# Epoch 45/50
# 29/29 - 0s - loss: 0.0978 - accuracy: 0.9804 - 29ms/epoch - 1000us/step
# Epoch 46/50
# 29/29 - 0s - loss: 0.0954 - accuracy: 0.9815 - 29ms/epoch - 1ms/step
# Epoch 47/50
# 29/29 - 0s - loss: 0.0944 - accuracy: 0.9815 - 27ms/epoch - 931us/step
# Epoch 48/50
# 29/29 - 0s - loss: 0.0936 - accuracy: 0.9815 - 28ms/epoch - 966us/step
# Epoch 49/50
# 29/29 - 0s - loss: 0.0909 - accuracy: 0.9815 - 27ms/epoch - 931us/step
# Epoch 50/50
# 29/29 - 0s - loss: 0.0900 - accuracy: 0.9782 - 29ms/epoch - 1ms/step

# %%
res=model.predict(scaled_X_test)
# Out:
# 15/15 [==============================] - 0s 855us/step

# %% [raw]
# res

# %%
print("A si crknu ????")
